# %%
# IMPORTING NECESSARY LIBRARIES
import numpy as np
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from keras.optimizers import SGD

# %%
# DATA PREPROCESSING AND CLEANING 
training_set = pd.read_csv('Airtel.csv')
training_set = training_set.iloc[:,1:2].values      #open prices
len(training_set)       #2D array 
training_set = training_set[~np.isnan(training_set)]
len(training_set)       #1D array
new_training_set = [[i] for i in training_set]      #converting back to 2D array
new_training_set = np.array(new_training_set) 
# new_training_set

# %%
plt.figure(figsize=(20,5))
plt.plot(new_training_set,color="green",label="Airtel Stock Price")
plt.legend()
plt.plot()
# Out:
# []

# %%
# FEATURE SCALING 
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler()
new_training_set = sc.fit_transform(new_training_set)

# %%
# CREATING INPUT DATA STREAM
x_train = new_training_set[:]
x_new_train=[]
y_train=[]
for i in range(0,3000):
    x_new_train.append([x_train[i:i+50]])
    y_train.append(x_train[i+50])


x_train = np.reshape(x_new_train,(3000,50,1))
y_train = np.array(y_train)

# %%
# BUILDING THE MODEL
model = Sequential()

model.add(LSTM(1000,input_shape=(50,1),return_sequences=True))
model.add(LSTM(500))
model.add(Dropout(0.2))
model.add(Dense(128))
model.add(Dense(1))

# %%
# COMPILING MODEL 
model.compile(optimizer="adam",loss="mean_squared_error")

# %%
# STRUCTURE OF THE MODEL
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_3 (LSTM)                (None, 50, 1000)          4008000
# _________________________________________________________________
# lstm_4 (LSTM)                (None, 500)               3002000
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 500)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 128)               64128
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 7,074,257
# Trainable params: 7,074,257
# Non-trainable params: 0
# _________________________________________________________________

# %%
# TRAINING THE MODEL ON THE TRAINING SET
model.fit(x_train,y_train,batch_size=256,epochs=200)
# Out:
# Epoch 1/200
# 3000/3000 [==============================] - 4s 1ms/step - loss: 0.0367
# Epoch 2/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 0.0016
# Epoch 3/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 7.0051e-04
# Epoch 4/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 5.1353e-04
# Epoch 5/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 4.7262e-04
# Epoch 6/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 3.7518e-04
# Epoch 7/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 3.7792e-04
# Epoch 8/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 3.7050e-04
# Epoch 9/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 3.3844e-04
# Epoch 10/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 3.2556e-04
# Epoch 11/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 3.1939e-04
# Epoch 12/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 3.1650e-04
# Epoch 13/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 3.1403e-04
# Epoch 14/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 2.9726e-04
# Epoch 15/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 3.2305e-04
# Epoch 16/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 2.8987e-04
# Epoch 17/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 2.8652e-04
# Epoch 18/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 2.9052e-04
# Epoch 19/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 3.0356e-04
# Epoch 20/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 3.1500e-04
# Epoch 21/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 3.4023e-04
# Epoch 22/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 3.0821e-04
# Epoch 23/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 3.1909e-04
# Epoch 24/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 3.1375e-04
# Epoch 25/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 2.6947e-04
# Epoch 26/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 3.0404e-04
# Epoch 27/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 2.7437e-04
# Epoch 28/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 2.6474e-04
# Epoch 29/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 2.9432e-04
# Epoch 30/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 3.2828e-04
# Epoch 31/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 3.7038e-04
# Epoch 32/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 2.7218e-04
# Epoch 33/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 2.7034e-04
# Epoch 34/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 2.6956e-04
# Epoch 35/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 2.6980e-04
# Epoch 36/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 2.6028e-04
# Epoch 37/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 2.8064e-04
# Epoch 38/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 2.4986e-04
# Epoch 39/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 2.7083e-04
# Epoch 40/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 2.4606e-04
# Epoch 41/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 2.5630e-04
# Epoch 42/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 2.3540e-04
# Epoch 43/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 2.4733e-04
# Epoch 44/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 2.4875e-04
# Epoch 45/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 2.3680e-04
# Epoch 46/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 2.3642e-04
# Epoch 47/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 2.2971e-04
# Epoch 48/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 2.4444e-04
# Epoch 49/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 2.2409e-04
# Epoch 50/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 2.4763e-04
# Epoch 51/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 2.4574e-04
# Epoch 52/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 2.3300e-04
# Epoch 53/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 2.5103e-04
# Epoch 54/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 2.3415e-04
# Epoch 55/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 2.6573e-04
# Epoch 56/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 2.3840e-04
# Epoch 57/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 2.2989e-04
# Epoch 58/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 2.1268e-04
# Epoch 59/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 2.0802e-04
# Epoch 60/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 2.2875e-04
# Epoch 61/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 2.3663e-04
# Epoch 62/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 2.3364e-04
# Epoch 63/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 2.3783e-04
# Epoch 64/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 2.4577e-04
# Epoch 65/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 2.6253e-04
# Epoch 66/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 2.8713e-04
# Epoch 67/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 2.4630e-04
# Epoch 68/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 2.4849e-04
# Epoch 69/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 2.3433e-04
# Epoch 70/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 2.0636e-04
# Epoch 71/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 1.9137e-04
# Epoch 72/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 2.0178e-04
# Epoch 73/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 2.0056e-04
# Epoch 74/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 1.9954e-04
# Epoch 75/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 2.0842e-04
# Epoch 76/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 2.0579e-04
# Epoch 77/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 2.0715e-04
# Epoch 78/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 2.1097e-04
# Epoch 79/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 2.1428e-04
# Epoch 80/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 2.2157e-04
# Epoch 81/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 1.9709e-04
# Epoch 82/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 1.9170e-04
# Epoch 83/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 2.0083e-04
# Epoch 84/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 1.9906e-04
# Epoch 85/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 1.8229e-04
# Epoch 86/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 2.0594e-04
# Epoch 87/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 1.9527e-04
# Epoch 88/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 1.8074e-04
# Epoch 89/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 1.8112e-04
# Epoch 90/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 1.8482e-04
# Epoch 91/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 1.8572e-04
# Epoch 92/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 1.8042e-04
# Epoch 93/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 1.8462e-04
# Epoch 94/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 1.8378e-04
# Epoch 95/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 1.8487e-04
# Epoch 96/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 1.7552e-04
# Epoch 97/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 1.9157e-04
# Epoch 98/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 1.8065e-04
# Epoch 99/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 2.0558e-04
# Epoch 100/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 1.9263e-04
# Epoch 101/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 1.6985e-04
# Epoch 102/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 1.6883e-04
# Epoch 103/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 1.6755e-04
# Epoch 104/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 1.8715e-04
# Epoch 105/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 1.7742e-04
# Epoch 106/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 1.7135e-04
# Epoch 107/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 1.7749e-04
# Epoch 108/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 1.9444e-04
# Epoch 109/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 1.9290e-04
# Epoch 110/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 1.8359e-04
# Epoch 111/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 1.6942e-04
# Epoch 112/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 1.6836e-04
# Epoch 113/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 1.6557e-04
# Epoch 114/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 1.6196e-04
# Epoch 115/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 1.6602e-04
# Epoch 116/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 1.7867e-04
# Epoch 117/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 1.7970e-04
# Epoch 118/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 1.6727e-04
# Epoch 119/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 1.6368e-04
# Epoch 120/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 1.6631e-04
# Epoch 121/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 1.6271e-04
# Epoch 122/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 1.6325e-04
# Epoch 123/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 1.6532e-04
# Epoch 124/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 1.6446e-04
# Epoch 125/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 1.6935e-04
# Epoch 126/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 1.7985e-04
# Epoch 127/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 1.7092e-04
# Epoch 128/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 1.5763e-04
# Epoch 129/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 1.6498e-04
# Epoch 130/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 1.6376e-04
# Epoch 131/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 1.5582e-04
# Epoch 132/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 1.5825e-04
# Epoch 133/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 1.6193e-04
# Epoch 134/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 1.6755e-04
# Epoch 135/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 1.5514e-04
# Epoch 136/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 1.4930e-04
# Epoch 137/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 1.5854e-04
# Epoch 138/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 1.5849e-04
# Epoch 139/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 1.6300e-04
# Epoch 140/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 1.6997e-04
# Epoch 141/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 1.6338e-04
# Epoch 142/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 1.5230e-04
# Epoch 143/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 1.5764e-04
# Epoch 144/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 1.5291e-04
# Epoch 145/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 1.5442e-04
# Epoch 146/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 1.4921e-04
# Epoch 147/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 1.6100e-04
# Epoch 148/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 1.8621e-04
# Epoch 149/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 1.8109e-04
# Epoch 150/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 1.9177e-04
# Epoch 151/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 1.7557e-04
# Epoch 152/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 1.6988e-04
# Epoch 153/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 1.6306e-04
# Epoch 154/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 1.4545e-04
# Epoch 155/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 1.5751e-04
# Epoch 156/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 1.5657e-04
# Epoch 157/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 1.4926e-04
# Epoch 158/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 1.4793e-04
# Epoch 159/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 1.5285e-04
# Epoch 160/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 1.5631e-04
# Epoch 161/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 1.5419e-04
# Epoch 162/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 1.4898e-04
# Epoch 163/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 1.4286e-04
# Epoch 164/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 1.5644e-04
# Epoch 165/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 1.5244e-04
# Epoch 166/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 1.5132e-04
# Epoch 167/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 1.4442e-04
# Epoch 168/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 1.4997e-04
# Epoch 169/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 1.6049e-04
# Epoch 170/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 1.5253e-04
# Epoch 171/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 1.5037e-04
# Epoch 172/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 1.4805e-04
# Epoch 173/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 1.6264e-04
# Epoch 174/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 1.5004e-04
# Epoch 175/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 1.5572e-04
# Epoch 176/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 1.7337e-04
# Epoch 177/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 1.6473e-04
# Epoch 178/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 1.5213e-04
# Epoch 179/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 1.4703e-04
# Epoch 180/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 1.5706e-04
# Epoch 181/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 1.5001e-04
# Epoch 182/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 1.4537e-04
# Epoch 183/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 1.4961e-04
# Epoch 184/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 1.5784e-04
# Epoch 185/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 1.5086e-04
# Epoch 186/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 1.4996e-04
# Epoch 187/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 1.4842e-04
# Epoch 188/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 1.5124e-04
# Epoch 189/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 1.5058e-04
# Epoch 190/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 1.4480e-04
# Epoch 191/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 1.5006e-04
# Epoch 192/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 1.4907e-04
# Epoch 193/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 1.4703e-04
# Epoch 194/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 1.5424e-04
# Epoch 195/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 1.6793e-04
# Epoch 196/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 1.5902e-04
# Epoch 197/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 1.5318e-04
# Epoch 198/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 1.4609e-04
# Epoch 199/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 1.5590e-04
# Epoch 200/200
# 3000/3000 [==============================] - 3s 1ms/step - loss: 1.5032e-04

# %%
# SAVING THE MODEL
model.save("model.h5")

# %% [markdown]
# # ***PREDICTION***

# %%
# IMPORTING LIBRARIES
import math
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler
from keras.models import load_model
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
# LOADING SAVED MODEL
model = load_model("model.h5")

# %%
# DATA PREPROCESSING AND CLEANING
test_set = pd.read_csv('AXISBANK.csv')
test_set = test_set.iloc[:,1:2].values #open prices
len(test_set)
test_set #2D array 
test_set = test_set[~np.isnan(test_set)]
test_set #1D array
len(test_set)
new_test_set = [[i] for i in test_set] #converting back to 2D array
new_test_set = np.array(new_test_set) 
new_test_set
# Out:
# array([[ 26.7 ],
#        [ 27.  ],
#        [ 26.  ],
#        ...,
#        [739.  ],
#        [760.9 ],
#        [753.85]])

# %%
# RETRIEVING REAL VALUES FROM TABLE 
real = []
for i in range(0,4900):
    real.append(new_test_set[i+50])
    

real = np.array(real)
real
# Out:
# array([[ 27.5],
#        [ 29.6],
#        [ 30.7],
#        ...,
#        [725. ],
#        [748. ],
#        [749. ]])

# %%
# NORMALIZATION
sc = MinMaxScaler()
new_test_set = sc.fit_transform(new_test_set)

# %%
# CREATING INPUT STREAM OF DATA 
x_train = new_test_set[:]
x_test=[]
y_test=[]
for i in range(2000,4900):
    x_test.append([x_train[i:i+50]])
    y_test.append(x_train[i+50])

x_test=np.reshape(x_test,(2900,50,1))
y_test=np.array(y_test)

# %%
# PREDICTION 
pred = model.predict(x_test)

# %%
# GETTING INVERSE TRANSFORMED VALUES OF PREDICTIONS 
pred = sc.inverse_transform(pred)
y_test_ = sc.inverse_transform(y_test)

# %%
pred
for i in range(2000):
    pred = np.insert(pred,0,[math.nan])

# %%
pred
# Out:
# array([      nan,       nan,       nan, ..., 717.62335, 723.8492 ,
#        740.86066], dtype=float32)

# %%
# VISUALIZATION OF PREDICTIONS VS REAL DATA
plt.figure(figsize=(20,5))
plt.plot(real,color="red",label="Real Airtel Stock Price")
plt.plot(pred,color="blue",label="Predicted Airtel Stock Price")
plt.title("Prediction Model")
plt.xlabel("Time")
plt.ylabel("Stock Price")
plt.xticks([])
plt.legend()    
plt.show()

# %% [markdown]
# # ***RETRIEVING BACK THE PREDICTIONS AND REAL VALUES***

# %%
pred = pred[~np.isnan(pred)]
new_pred = [[i] for i in pred]      #converting back to 2D array
new_pred = np.array(new_pred) 
new_pred
# Out:
# array([[987.56757],
#        [996.61615],
#        [973.0455 ],
#        ...,
#        [717.62335],
#        [723.8492 ],
#        [740.86066]], dtype=float32)

# %%
real = real[2000:4900]

# %%
# CALCULATION OF RMSE VALUE
rmse = math.sqrt(mean_squared_error(real,pred))
print("rmse is:", '{0:.2f}'.format((rmse/2900)*100),"%")
# Out:
# rmse is: 1.39 %
