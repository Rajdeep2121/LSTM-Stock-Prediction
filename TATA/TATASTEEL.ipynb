# %%
# IMPORTING NECESSARY LIBRARIES
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from keras.optimizers import SGD
# Out:
# Using TensorFlow backend.

# %%
# DATA PREPROCESSING AND CLEANING 
training_set = pd.read_csv('TATASTEEL.csv')
training_set = training_set.iloc[:,1:2].values      #open prices
len(training_set)       #2D array 
training_set = training_set[~np.isnan(training_set)]
len(training_set)       #1D array
new_training_set = [[i] for i in training_set]      #converting back to 2D array
new_training_set = np.array(new_training_set) 
# new_training_set

# %%
plt.figure(figsize=(20,5))
plt.plot(new_training_set,color="green",label="TATA Steel Stock Price")
plt.legend()
plt.show()

# %%
# FEATURE SCALING 
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler()
new_training_set = sc.fit_transform(new_training_set)

# %%
# CREATING INPUT DATA STREAM
x_train = new_training_set[:]
x_new_train=[]
y_train=[]
for i in range(0,3000):
    x_new_train.append([x_train[i:i+50]])
    y_train.append(x_train[i+50])


x_train = np.reshape(x_new_train,(3000,50,1))
y_train = np.array(y_train)

# %%
# BUILDING THE MODEL
model = Sequential()

model.add(LSTM(1000,input_shape=(50,1),return_sequences=True))
model.add(LSTM(500))
model.add(Dropout(0.2))
model.add(Dense(128))
model.add(Dense(1))

# %%
# COMPILING MODEL 
model.compile(optimizer="adam",loss="mean_squared_error")

# %%
# STRUCTURE OF THE MODEL
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 50, 1000)          4008000
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 500)               3002000
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 500)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               64128
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 7,074,257
# Trainable params: 7,074,257
# Non-trainable params: 0
# _________________________________________________________________

# %%
# TRAINING THE MODEL ON THE TRAINING SET
model.fit(x_train,y_train,batch_size=256,epochs=200)
# Out:
# Epoch 1/200
# 3000/3000 [==============================] - 8s 3ms/step - loss: 0.0442
# Epoch 2/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 0.0043
# Epoch 3/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 0.0015
# Epoch 4/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 9.3311e-04
# Epoch 5/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 8.6805e-04
# Epoch 6/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 7.7788e-04
# Epoch 7/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 7.2955e-04
# Epoch 8/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 6.7006e-04
# Epoch 9/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 7.1790e-04
# Epoch 10/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 7.0881e-04
# Epoch 11/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 6.4084e-04
# Epoch 12/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 6.5353e-04
# Epoch 13/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 6.1632e-04
# Epoch 14/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 6.2620e-04
# Epoch 15/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 6.0102e-04
# Epoch 16/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 5.6163e-04
# Epoch 17/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 5.8142e-04
# Epoch 18/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 5.5600e-04
# Epoch 19/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 5.8224e-04
# Epoch 20/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 5.8779e-04
# Epoch 21/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 6.2301e-04
# Epoch 22/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 5.7957e-04
# Epoch 23/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 5.4039e-04
# Epoch 24/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 6.1044e-04
# Epoch 25/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 5.6838e-04
# Epoch 26/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 5.4259e-04
# Epoch 27/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 5.8442e-04
# Epoch 28/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 5.2161e-04
# Epoch 29/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 5.3584e-04
# Epoch 30/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 5.1303e-04
# Epoch 31/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 5.1927e-04
# Epoch 32/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 5.1029e-04
# Epoch 33/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 5.0669e-04
# Epoch 34/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 5.0540e-04
# Epoch 35/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 4.8506e-04
# Epoch 36/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 4.9768e-04
# Epoch 37/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 4.9121e-04
# Epoch 38/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 5.7384e-04
# Epoch 39/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 5.0439e-04
# Epoch 40/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 4.8080e-04
# Epoch 41/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 4.8233e-04
# Epoch 42/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 4.7832e-04
# Epoch 43/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 4.6461e-04
# Epoch 44/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 4.7066e-04
# Epoch 45/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 4.8733e-04
# Epoch 46/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 4.5786e-04
# Epoch 47/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 4.5141e-04
# Epoch 48/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 5.0329e-04
# Epoch 49/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 5.0931e-04
# Epoch 50/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 4.7654e-04
# Epoch 51/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 4.3378e-04
# Epoch 52/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 4.4388e-04
# Epoch 53/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 4.3516e-04
# Epoch 54/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 4.4106e-04
# Epoch 55/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 4.5522e-04
# Epoch 56/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 4.7238e-04
# Epoch 57/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 4.2383e-04
# Epoch 58/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 5.1686e-04
# Epoch 59/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 4.5057e-04
# Epoch 60/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 4.4947e-04
# Epoch 61/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 4.2086e-04
# Epoch 62/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 4.3318e-04
# Epoch 63/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 4.0170e-04
# Epoch 64/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 4.1846e-04
# Epoch 65/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 4.0446e-04
# Epoch 66/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 3.9326e-04
# Epoch 67/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 4.0756e-04
# Epoch 68/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 4.3690e-04
# Epoch 69/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 4.0028e-04
# Epoch 70/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 4.0286e-04
# Epoch 71/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 4.0104e-04
# Epoch 72/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 4.5942e-04
# Epoch 73/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 4.2698e-04
# Epoch 74/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 4.2959e-04
# Epoch 75/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 4.0767e-04
# Epoch 76/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 4.0223e-04
# Epoch 77/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 4.1121e-04
# Epoch 78/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 4.2241e-04
# Epoch 79/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 4.0134e-04
# Epoch 80/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 3.7772e-04
# Epoch 81/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 3.9481e-04
# Epoch 82/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 3.8203e-04
# Epoch 83/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 3.7099e-04
# Epoch 84/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 3.8921e-04
# Epoch 85/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 3.7605e-04
# Epoch 86/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 3.7645e-04
# Epoch 87/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 3.9600e-04
# Epoch 88/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 3.9808e-04
# Epoch 89/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 3.6932e-04
# Epoch 90/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 3.5587e-04
# Epoch 91/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 3.6465e-04
# Epoch 92/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 3.8953e-04
# Epoch 93/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 3.7884e-04
# Epoch 94/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 3.6556e-04
# Epoch 95/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 3.7065e-04
# Epoch 96/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 4.3254e-04
# Epoch 97/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 4.8531e-04
# Epoch 98/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 4.2128e-04
# Epoch 99/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 4.1373e-04
# Epoch 100/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 4.2857e-04
# Epoch 101/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 3.8297e-04
# Epoch 102/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 3.6918e-04
# Epoch 103/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 3.4698e-04
# Epoch 104/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 3.3978e-04
# Epoch 105/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 3.5082e-04
# Epoch 106/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 3.7457e-04
# Epoch 107/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 3.5002e-04
# Epoch 108/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 3.5867e-04
# Epoch 109/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 3.6135e-04
# Epoch 110/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 3.4193e-04
# Epoch 111/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 3.4420e-04
# Epoch 112/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 3.4541e-04
# Epoch 113/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 3.7584e-04
# Epoch 114/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 3.6305e-04
# Epoch 115/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 3.3925e-04
# Epoch 116/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 3.3224e-04
# Epoch 117/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 3.4658e-04
# Epoch 118/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 3.5445e-04
# Epoch 119/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 3.5177e-04
# Epoch 120/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 3.4345e-04
# Epoch 121/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 3.5859e-04
# Epoch 122/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 3.3852e-04
# Epoch 123/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 3.5022e-04
# Epoch 124/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 3.3294e-04
# Epoch 125/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 3.5398e-04
# Epoch 126/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 3.5775e-04
# Epoch 127/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 3.4283e-04
# Epoch 128/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 3.2824e-04
# Epoch 129/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 3.3254e-04
# Epoch 130/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 3.4216e-04
# Epoch 131/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 3.4208e-04
# Epoch 132/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 3.6295e-04
# Epoch 133/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 3.4813e-04
# Epoch 134/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 3.2470e-04
# Epoch 135/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 3.6040e-04
# Epoch 136/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 3.5060e-04
# Epoch 137/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 3.2326e-04
# Epoch 138/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 3.3020e-04
# Epoch 139/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 3.4642e-04
# Epoch 140/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 3.5591e-04
# Epoch 141/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 3.2270e-04
# Epoch 142/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 3.2479e-04
# Epoch 143/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 3.3187e-04
# Epoch 144/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 3.3577e-04
# Epoch 145/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 3.2036e-04
# Epoch 146/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 3.3009e-04
# Epoch 147/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 3.3877e-04
# Epoch 148/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 3.5007e-04
# Epoch 149/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 3.2779e-04
# Epoch 150/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 3.2647e-04
# Epoch 151/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 3.2541e-04
# Epoch 152/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 3.5682e-04
# Epoch 153/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 3.2647e-04
# Epoch 154/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 3.2002e-04
# Epoch 155/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 3.2733e-04
# Epoch 156/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 3.2903e-04
# Epoch 157/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 3.3910e-04
# Epoch 158/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 3.2127e-04
# Epoch 159/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 3.3110e-04
# Epoch 160/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 3.4126e-04
# Epoch 161/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 3.4085e-04
# Epoch 162/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 3.2140e-04
# Epoch 163/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 3.4930e-04
# Epoch 164/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 3.4233e-04
# Epoch 165/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 3.4877e-04
# Epoch 166/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 3.8482e-04
# Epoch 167/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 3.2205e-04
# Epoch 168/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 3.2364e-04
# Epoch 169/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 3.1792e-04
# Epoch 170/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 3.9489e-04
# Epoch 171/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 4.0568e-04
# Epoch 172/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 3.5169e-04
# Epoch 173/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 3.1512e-04
# Epoch 174/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 3.5503e-04
# Epoch 175/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 3.8706e-04
# Epoch 176/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 3.7431e-04
# Epoch 177/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 3.5059e-04
# Epoch 178/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 3.1769e-04
# Epoch 179/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 3.3270e-04
# Epoch 180/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 3.1593e-04
# Epoch 181/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 3.0770e-04
# Epoch 182/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 3.2047e-04
# Epoch 183/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 3.3216e-04
# Epoch 184/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 3.1456e-04
# Epoch 185/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 3.2445e-04
# Epoch 186/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 3.1918e-04
# Epoch 187/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 3.2557e-04
# Epoch 188/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 3.2162e-04
# Epoch 189/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 3.2678e-04
# Epoch 190/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 3.3204e-04
# Epoch 191/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 3.4180e-04
# Epoch 192/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 3.1095e-04
# Epoch 193/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 3.1820e-04
# Epoch 194/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 3.2861e-04
# Epoch 195/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 3.2161e-04
# Epoch 196/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 3.2930e-04
# Epoch 197/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 3.2744e-04
# Epoch 198/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 3.1968e-04
# Epoch 199/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 3.0975e-04
# Epoch 200/200
# 3000/3000 [==============================] - 6s 2ms/step - loss: 3.1652e-04

# %%
# SAVING THE MODEL
model.save("model.h5")

# %% [markdown]
# # ***PREDICTION***

# %%
# IMPORTING LIBRARIES
import math
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler
from keras.models import load_model
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
# LOADING SAVED MODEL
model = load_model("model.h5")

# %%
# DATA PREPROCESSING AND CLEANING
test_set = pd.read_csv('TATASTEEL.csv')
test_set = test_set.iloc[:,1:2].values #open prices
len(test_set)
test_set #2D array 
test_set = test_set[~np.isnan(test_set)]
test_set #1D array
len(test_set)
new_test_set = [[i] for i in test_set] #converting back to 2D array
new_test_set = np.array(new_test_set) 
new_test_set
# Out:
# array([[148.  ],
#        [150.1 ],
#        [144.6 ],
#        ...,
#        [469.25],
#        [470.1 ],
#        [472.65]])

# %%
# RETRIEVING REAL VALUES FROM TABLE 
real = []
for i in range(0,4900):
    real.append(new_test_set[i+50])
    

real = np.array(real)
len(real)
# Out:
# 4900

# %%
# NORMALIZATION
sc = MinMaxScaler()
new_test_set = sc.fit_transform(new_test_set)

# %%
# CREATING INPUT STREAM OF DATA 
x_train = new_test_set[:]
x_test=[]
y_test=[]
for i in range(3000,4900):
    x_test.append([x_train[i:i+50]])
    y_test.append(x_train[i+50])

x_test=np.reshape(x_test,(1900,50,1))
y_test=np.array(y_test)

# %%
# PREDICTION 
pred = model.predict(x_test)

# %%
# GETTING INVERSE TRANSFORMED VALUES OF PREDICTIONS 
pred = sc.inverse_transform(pred)
y_test_ = sc.inverse_transform(y_test)

# %%
pred
for i in range(3000):
    pred = np.insert(pred,0,[math.nan])

# %%
# VISUALIZATION OF PREDICTIONS VS REAL DATA
plt.figure(figsize=(20,5))
plt.plot(real,color="red",label="Real TATA Steel Stock Price")
plt.plot(pred,color="blue",label="Predicted TATA Steel Stock Price")
plt.title("Prediction Model")
plt.xlabel("Time")
plt.ylabel("Stock Price")
plt.legend()    
plt.show()

# %% [markdown]
# # ***RETRIEVING PREDICTION AND REAL VALUES***

# %%
pred = pred[~np.isnan(pred)]
new_pred = [[i] for i in pred]      #converting back to 2D array
new_pred = np.array(new_pred) 
new_pred
# Out:
# array([[464.53125],
#        [456.52515],
#        [454.78845],
#        ...,
#        [390.77722],
#        [405.5673 ],
#        [399.98914]], dtype=float32)

# %%
real = real[3000:4900]

# %%
# CALCULATION OF RMSE VALUE
rmse = math.sqrt(mean_squared_error(real,new_pred))
print("rmse is:", '{0:.2f}'.format((rmse/1900)*100),"%")
# Out:
# rmse is: 0.60 %
